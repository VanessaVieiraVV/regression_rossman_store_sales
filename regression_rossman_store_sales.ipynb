# %% [markdown]
# # 0.0. IMPORTS

# %%
import math
import numpy  as np
import pandas as pd
import random
import pickle
import warnings
import inflection
import seaborn as sns
import xgboost as xgb

from tqdm                     import tqdm
from scipy                    import stats  as ss
from boruta                   import BorutaPy
from tabulate                 import tabulate
from lightgbm                 import LGBMRegressor
from matplotlib               import pyplot as plt
from IPython.display          import Image
from IPython.core.display     import HTML


from sklearn.metrics          import mean_absolute_error, mean_squared_error
from sklearn.ensemble         import RandomForestRegressor
from sklearn.linear_model     import LinearRegression, Lasso
from sklearn.preprocessing    import RobustScaler, MinMaxScaler, LabelEncoder
from sklearn.model_selection  import KFold,train_test_split,  ParameterGrid

warnings.filterwarnings( 'ignore' )

# %% [markdown]
# ## 0.1. Helper Functions

# %%
def cross_validation( x_training, kfold, model_name, model, verbose=False ):
    mae_list = []
    mape_list = []
    rmse_list = []
    for k in reversed( range( 1, kfold+1 ) ):
        if verbose:
            print( '\nKFold Number: {}'.format( k ) )
        # start and end date for validation 
        validation_start_date = x_training['date'].max() - datetime.timedelta( days=k*6*7)
        validation_end_date = x_training['date'].max() - datetime.timedelta( days=(k-1)*6*7)

        # filtering dataset
        training = x_training[x_training['date'] < validation_start_date]
        validation = x_training[(x_training['date'] >= validation_start_date) & (x_training['date'] <= validation_end_date)]

        # training and validation dataset
        # training
        xtraining = training.drop( ['date', 'sales'], axis=1 ) 
        ytraining = training['sales']

        # validation
        xvalidation = validation.drop( ['date', 'sales'], axis=1 )
        yvalidation = validation['sales']

        # model
        m = model.fit( xtraining, ytraining )

        # prediction
        yhat = m.predict( xvalidation )

        # performance
        m_result = ml_error( model_name, np.expm1( yvalidation ), np.expm1( yhat ) )

        # store performance of each kfold iteration
        mae_list.append(  m_result['MAE'] )
        mape_list.append( m_result['MAPE'] )
        rmse_list.append( m_result['RMSE'] )

    return pd.DataFrame( {'Model Name': model_name,
                          'MAE CV': np.round( np.mean( mae_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( mae_list ), 2 ).astype( str ),
                          'MAPE CV': np.round( np.mean( mape_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( mape_list ), 2 ).astype( str ),
                          'RMSE CV': np.round( np.mean( rmse_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( rmse_list ), 2 ).astype( str ) }, index=[0] )


def mean_percentage_error( y, yhat ):
    return np.mean( ( y - yhat ) / y )
     
    
def mean_absolute_percentage_error( y, yhat ):
    return np.mean( np.abs( ( y - yhat ) / y ) )

    
def ml_error( model_name, y, yhat ):
    mae = mean_absolute_error( y, yhat )
    mape = mean_absolute_percentage_error( y, yhat )
    rmse = np.sqrt( mean_squared_error( y, yhat ) )
    
    return pd.DataFrame( { 'Model Name': model_name, 
                           'MAE': mae, 
                           'MAPE': mape,
                           'RMSE': rmse }, index=[0] )

def cramer_v( x, y ):
    cm = pd.crosstab( x, y ).values
    n = cm.sum()
    r, k = cm.shape
    
    chi2 = ss.chi2_contingency( cm )[0]
    chi2corr = max( 0, chi2 - (k-1)*(r-1)/(n-1) )
    
    kcorr = k - (k-1)**2/(n-1)
    rcorr = r - (r-1)**2/(n-1)
    
    return np.sqrt( (chi2corr/n) / ( min( kcorr-1, rcorr-1 ) ) )



def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2. Loading data

# %%
df_sales_raw = pd.read_csv( '../data/train.csv', low_memory=False )
df_store_raw = pd.read_csv( '../data/store.csv', low_memory=False )

# merge
df_raw = pd.merge( df_sales_raw, df_store_raw, how='left', on='Store' )

# %% [markdown]
# # 1.0. STEP 01 - DESCRICAO DOS DADOS

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1. Rename Columns

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', 
            'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
            'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']

snakecase = lambda x: inflection.underscore( x )

cols_new = list( map( snakecase, cols_old ) )

# rename
df1.columns = cols_new

# %% [markdown]
# ## 1.2. Data Dimensions

# %%
print( 'Number of Rows: {}'.format( df1.shape[0] ) )
print( 'Number of Cols: {}'.format( df1.shape[1] ) )
# Out:
# Number of Rows: 1017209
# Number of Cols: 18

# %% [markdown]
# ## 1.3. Data Types

# %%
df1['date'] = pd.to_datetime( df1['date'] )
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4. Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5. Fillout NA

# %%
df1.sample()
# Out:
#         store  day_of_week       date  sales  customers  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year   promo_interval
# 333738    146            4 2014-09-18   8270        725     1      1             0               0          d          c                8050.0                          10.0                       1961.0       1               48.0             2012.0  Jan,Apr,Jul,Oct

# %%
df1['competition_distance'] = df1['competition_distance'].apply( lambda x: 200000.0 if math.isnan( x ) else x )

df1['competition_open_since_month'] = df1.apply( lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] ) else x['competition_open_since_month'], axis=1 )

df1['competition_open_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] ) else x['competition_open_since_year'], axis=1 )

df1['promo2_since_week'] = df1.apply( lambda x: x['date'].week if math.isnan( x['promo2_since_week'] ) else x['promo2_since_week'], axis=1 )
           
df1['promo2_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['promo2_since_year'] ) else x['promo2_since_year'], axis=1 )

#promo_interval              
month_map = {1: 'Jan',  2: 'Fev',  3: 'Mar',  4: 'Apr',  5: 'May',  6: 'Jun',  7: 'Jul',  8: 'Aug',  9: 'Sep',  10: 'Oct', 11: 'Nov', 12: 'Dec'}

df1['promo_interval'].fillna(0, inplace=True )

df1['month_map'] = df1['date'].dt.month.map( month_map )

df1['is_promo'] = df1[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 )

# %%
df1.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# month_map                       0
# is_promo                        0
# dtype: int64

# %% [markdown]
# ## 1.6. Change Data Types

# %%
# competiton
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype( int )
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype( int )
    
# promo2
df1['promo2_since_week'] = df1['promo2_since_week'].astype( int )
df1['promo2_since_year'] = df1['promo2_since_year'].astype( int )

# %% [markdown]
# ## 1.7. Descriptive Statistics

# %%
num_attributes = df1.select_dtypes( include=['int64', 'float64'] )
cat_attributes = df1.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'] )

# %% [markdown]
# ### 1.7.1. Numerical Atributes

# %%
# Central Tendency - mean, meadina 
ct1 = pd.DataFrame( num_attributes.apply( np.mean ) ).T
ct2 = pd.DataFrame( num_attributes.apply( np.median ) ).T

# dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame( num_attributes.apply( np.std ) ).T 
d2 = pd.DataFrame( num_attributes.apply( min ) ).T 
d3 = pd.DataFrame( num_attributes.apply( max ) ).T 
d4 = pd.DataFrame( num_attributes.apply( lambda x: x.max() - x.min() ) ).T 
d5 = pd.DataFrame( num_attributes.apply( lambda x: x.skew() ) ).T 
d6 = pd.DataFrame( num_attributes.apply( lambda x: x.kurtosis() ) ).T 

# concatenar
m = pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#              attributes   min       max     range         mean  median           std       skew    kurtosis
# 0                 store   1.0    1115.0    1114.0   558.429727   558.0    321.908493  -0.000955   -1.200524
# 1           day_of_week   1.0       7.0       6.0     3.998341     4.0      1.997390   0.001593   -1.246873
# 2                 sales   0.0   41551.0   41551.0  5773.818972  5744.0   3849.924283   0.641460    1.778375
# 3             customers   0.0    7388.0    7388.0   633.145946   609.0    464.411506   1.598650    7.091773
# 4                  open   0.0       1.0       1.0     0.830107     1.0      0.375539  -1.758045    1.090723
# 5                 promo   0.0       1.0       1.0     0.381515     0.0      0.485758   0.487838   -1.762018
# 6        school_holiday   0.0       1.0       1.0     0.178647     0.0      0.383056   1.677842    0.815154
# 7  competition_distance  20.0  200000.0  199980.0  5935.442677  2330.0  12547.646829  10.242344  147.789712
# 8                promo2   0.0       1.0       1.0     0.500564     1.0      0.500000  -0.002255   -1.999999
# 9              is_promo   0.0       1.0       1.0     0.155231     0.0      0.362124   1.904152    1.625796

# %%
sns.distplot( df1['competition_distance'], kde=False )
# Out:
# <AxesSubplot:xlabel='competition_distance'>

# %% [markdown]
# ### 1.7.2. Categorical Atributes

# %%
cat_attributes.apply( lambda x: x.unique().shape[0] )
# Out:
# state_holiday                    4
# store_type                       4
# assortment                       3
# competition_open_since_month    12
# competition_open_since_year     23
# promo2_since_week               52
# promo2_since_year                7
# promo_interval                   4
# month_map                       12
# dtype: int64

# %%
aux = df1[(df1['state_holiday'] != '0') & (df1['sales'] > 0)]

plt.subplot( 1, 3, 1 )
sns.boxplot( x='state_holiday', y='sales', data=aux )

plt.subplot( 1, 3, 2 )
sns.boxplot( x='store_type', y='sales', data=aux )

plt.subplot( 1, 3, 3 )
sns.boxplot( x='assortment', y='sales', data=aux )
# Out:
# <AxesSubplot:xlabel='assortment', ylabel='sales'>

# %% [markdown]
# # 2.0. STEP 02 - FEATURE ENGINEERING

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1. Hypothesis Mind Map

# %%
Image( '../img/hypothesis-mindmap.png' )

# %% [markdown]
# ## 2.2. Hypothesis Creation

# %% [markdown]
# ### 2.2.1. Hipoteses Loja

# %% [markdown]
# **1.** Lojas com número maior de funcionários deveriam vender mais.
#
# **2.** Lojas com maior capacidade de estoque deveriam vender mais.
#
# **3.** Lojas com maior porte deveriam vender mais.
#
# **4.** Lojas com maior sortimentos deveriam vender mais.
#
# **5.** Lojas com competidores mais próximos deveriam vender menos.
#
# **6.** Lojas com competidores à mais tempo deveriam vendem mais.

# %% [markdown]
# ### 2.2.2. Hipoteses Produto

# %% [markdown]
# **1.** Lojas que investem mais em Marketing deveriam vender mais.
#
# **2.** Lojas com maior exposição de produto deveriam vender mais.
#
# **3.** Lojas com produtos com preço menor deveriam vender mais.
#
# **5.** Lojas com promoções mais agressivas ( descontos maiores ), deveriam vender mais.
#
# **6.** Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **7.** Lojas com mais dias de promoção deveriam vender mais.
#
# **8.** Lojas com mais promoções consecutivas deveriam vender mais.

# %% [markdown]
# ### 2.2.3. Hipoteses Tempo

# %% [markdown]
# **1.** Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **2.** Lojas deveriam vender mais ao longo dos anos.
#
# **3.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **4.** Lojas deveriam vender mais depois do dia 10 de cada mês.
#
# **5.** Lojas deveriam vender menos aos finais de semana.
#
# **6.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.3. Lista Final de Hipóteses

# %% [markdown]
# **1.** Lojas com maior sortimentos deveriam vender mais.
#
# **2.** Lojas com competidores mais próximos deveriam vender menos.
#
# **3.** Lojas com competidores à mais tempo deveriam vendem mais.

# %% [markdown]
# **4.** Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **5.** Lojas com mais dias de promoção deveriam vender mais.
#
# **7.** Lojas com mais promoções consecutivas deveriam vender mais.

# %% [markdown]
# **8.** Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **9.** Lojas deveriam vender mais ao longo dos anos.
#
# **10.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **11.** Lojas deveriam vender mais depois do dia 10 de cada mês.
#
# **12.** Lojas deveriam vender menos aos finais de semana.
#
# **13.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.4. Feature Engineering

# %%
# year
df2['year'] = df2['date'].dt.year

# month
df2['month'] = df2['date'].dt.month

# day
df2['day'] = df2['date'].dt.day

# week of year
df2['week_of_year'] = df2['date'].dt.weekofyear

# year week
df2['year_week'] = df2['date'].dt.strftime( '%Y-%W' )

# competition since
df2['competition_since'] = df2.apply( lambda x: datetime.datetime( year=x['competition_open_since_year'], month=x['competition_open_since_month'],day=1 ), axis=1 )
df2['competition_time_month'] = ( ( df2['date'] - df2['competition_since'] )/30 ).apply( lambda x: x.days ).astype( int )

# promo since
df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )
df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta( days=7 ) )
df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply( lambda x: x.days ).astype( int )

# assortment
df2['assortment'] = df2['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )

# state holiday
df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day' )

# %% [markdown]
# # 3.0. STEP 03 - FILTERING OF VARIABLES

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1. Line Filtering

# %%
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2. Columns Selection

# %%
cols_drop = ['customers', 'open', 'promo_interval', 'month_map']
df3 = df3.drop( cols_drop, axis=1 )

# %% [markdown]
# # 4.0. STEP 04 - EXPLORATORY DATA ANALYSIS

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1. Univariate Analysis

# %% [markdown]
# ### 4.1.1. Response Variable

# %%
sns.distplot( df4['sales'], kde=False  )
# Out:
# <AxesSubplot:xlabel='sales'>

# %% [markdown]
# ### 4.1.2. Numerical Variable

# %%
num_attributes.hist( bins=25 );

# %% [markdown]
# ### 4.1.3. Categorical Variable

# %%
# state_holiday
plt.subplot( 3, 2, 1 )
a = df4[df4['state_holiday'] != 'regular_day']
sns.countplot( a['state_holiday'] )

plt.subplot( 3, 2, 2 )
sns.kdeplot( df4[df4['state_holiday'] == 'public_holiday']['sales'], label='public_holiday', shade=True )
sns.kdeplot( df4[df4['state_holiday'] == 'easter_holiday']['sales'], label='easter_holiday', shade=True )
sns.kdeplot( df4[df4['state_holiday'] == 'christmas']['sales'], label='christmas', shade=True )

# store_type
plt.subplot( 3, 2, 3 )
sns.countplot( df4['store_type'] )

plt.subplot( 3, 2, 4 )
sns.kdeplot( df4[df4['store_type'] == 'a']['sales'], label='a', shade=True )
sns.kdeplot( df4[df4['store_type'] == 'b']['sales'], label='b', shade=True )
sns.kdeplot( df4[df4['store_type'] == 'c']['sales'], label='c', shade=True )
sns.kdeplot( df4[df4['store_type'] == 'd']['sales'], label='d', shade=True )

# assortment
plt.subplot( 3, 2, 5 )
sns.countplot( df4['assortment'] )

plt.subplot( 3, 2, 6 )
sns.kdeplot( df4[df4['assortment'] == 'extended']['sales'], label='extended', shade=True )
sns.kdeplot( df4[df4['assortment'] == 'basic']['sales'], label='basic', shade=True )
sns.kdeplot( df4[df4['assortment'] == 'extra']['sales'], label='extra', shade=True )
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# ## 4.2. Bivariate Analysis

# %% [markdown]
# ### **H1.** Lojas com maior sortimentos deveriam vender mais.
# **FALSA** Lojas com MAIOR SORTIMENTO vendem MENOS.

# %%
aux1 = df4[['assortment', 'sales']].groupby( 'assortment' ).sum().reset_index()
sns.barplot( x='assortment', y='sales', data=aux1 );

aux2 = df4[['year_week', 'assortment', 'sales']].groupby( ['year_week','assortment'] ).sum().reset_index()
aux2.pivot( index='year_week', columns='assortment', values='sales' ).plot()

aux3 = aux2[aux2['assortment'] == 'extra']
aux3.pivot( index='year_week', columns='assortment', values='sales' ).plot()
# Out:
# <AxesSubplot:xlabel='year_week'>

# %% [markdown]
# ### **H2.** Lojas com competidores mais próximos deveriam vender menos.
# **FALSA** Lojas com COMPETIDORES MAIS PROXIMOS vendem MAIS.

# %%
aux1 = df4[['competition_distance', 'sales']].groupby( 'competition_distance' ).sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.scatterplot( x ='competition_distance', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
bins = list( np.arange( 0, 20000, 1000) )
aux1['competition_distance_binned'] = pd.cut( aux1['competition_distance'], bins=bins )
aux2 = aux1[['competition_distance_binned', 'sales']].groupby( 'competition_distance_binned' ).sum().reset_index()
sns.barplot( x='competition_distance_binned', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot( 1, 3, 3 )
x = sns.heatmap( aux1.corr( method='pearson' ), annot=True );
bottom, top = x.get_ylim()
x.set_ylim( bottom+0.5, top-0.5 );

# %% [markdown]
# ### **H3.** Lojas com competidores à mais tempo deveriam vendem mais.
# **FALSE** Lojas com COMPETIDORES À MAIS TEMPO vendem MENOS.

# %%
plt.subplot( 1, 3, 1 )
aux1 = df4[['competition_time_month', 'sales']].groupby( 'competition_time_month' ).sum().reset_index()
aux2 = aux1[( aux1['competition_time_month'] < 120 ) & ( aux1['competition_time_month'] != 0 )]
sns.barplot( x='competition_time_month', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='competition_time_month', y='sales', data=aux2 );

plt.subplot( 1, 3, 3 )
x = sns.heatmap( aux1.corr( method='pearson'), annot=True );
bottom, top = x.get_ylim()
x.set_ylim( bottom+0.5, top-0.5);

# %% [markdown]
# ### **H4.** Lojas com promoções ativas por mais tempo deveriam vender mais.
# **FALSA** Lojas com promocoes ativas por mais tempo vendem menos, depois de um certo periodo de promocao

# %%
aux1 = df4[['promo_time_week', 'sales']].groupby( 'promo_time_week').sum().reset_index()

grid = GridSpec( 2, 3 )

plt.subplot( grid[0,0] )
aux2 = aux1[aux1['promo_time_week'] > 0] # promo extendido
sns.barplot( x='promo_time_week', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot( grid[0,1] )
sns.regplot( x='promo_time_week', y='sales', data=aux2 );

plt.subplot( grid[1,0] )
aux3 = aux1[aux1['promo_time_week'] < 0] # promo regular
sns.barplot( x='promo_time_week', y='sales', data=aux3 );
plt.xticks( rotation=90 );

plt.subplot( grid[1,1] )
sns.regplot( x='promo_time_week', y='sales', data=aux3 );

plt.subplot( grid[:,2] )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### <s>**H5.** Lojas com mais dias de promoção deveriam vender mais.</s>

# %% [markdown]
# ### **H7.** Lojas com mais promoções consecutivas deveriam vender mais.
# **FALSA** Lojas com mais promocoes consecutivas vendem menos

# %%
df4[['promo', 'promo2', 'sales']].groupby( ['promo', 'promo2'] ).sum().reset_index()
# Out:
#    promo  promo2       sales
# 0      0       0  1482612096
# 1      0       1  1289362241
# 2      1       0  1628930532
# 3      1       1  1472275754

# %%
aux1 = df4[( df4['promo'] == 1 ) & ( df4['promo2'] == 1 )][['year_week', 'sales']].groupby( 'year_week' ).sum().reset_index()
ax = aux1.plot()

aux2 = df4[( df4['promo'] == 1 ) & ( df4['promo2'] == 0 )][['year_week', 'sales']].groupby( 'year_week' ).sum().reset_index()
aux2.plot( ax=ax )

ax.legend( labels=['Tradicional & Extendida', 'Extendida']);

# %% [markdown]
# ### **H8.** Lojas abertas durante o feriado de Natal deveriam vender mais.
# **FALSA** Lojas abertas durante o feriado do Natal vendem menos.

# %%
aux = df4[df4['state_holiday'] != 'regular_day']

plt.subplot( 1, 2, 1 )
aux1 = aux[['state_holiday', 'sales']].groupby( 'state_holiday' ).sum().reset_index()
sns.barplot( x='state_holiday', y='sales', data=aux1 );

plt.subplot( 1, 2, 2 )
aux2 = aux[['year', 'state_holiday', 'sales']].groupby( ['year', 'state_holiday'] ).sum().reset_index()
sns.barplot( x='year', y='sales', hue='state_holiday', data=aux2 );

# %% [markdown]
# ### **H9.** Lojas deveriam vender mais ao longo dos anos.
# **FALSA** Lojas vendem menos ao longo dos anos

# %%
aux1 = df4[['year', 'sales']].groupby( 'year' ).sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.barplot( x='year', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='year', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### **H10.** Lojas deveriam vender mais no segundo semestre do ano.
# **FALSA** Lojas vendem menos no segundo semestre do ano

# %%
aux1 = df4[['month', 'sales']].groupby( 'month' ).sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.barplot( x='month', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='month', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### **H11.** Lojas deveriam vender mais depois do dia 10 de cada mês.
# **VERDADEIRA** Lojas vendem mais depois do dia 10 de cada mes.

# %%
aux1 = df4[['day', 'sales']].groupby( 'day' ).sum().reset_index()

plt.subplot( 2, 2, 1 )
sns.barplot( x='day', y='sales', data=aux1 );

plt.subplot( 2, 2, 2 )
sns.regplot( x='day', y='sales', data=aux1 );

plt.subplot( 2, 2, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

aux1['before_after'] = aux1['day'].apply( lambda x: 'before_10_days' if x <= 10 else 'after_10_days' )
aux2 =aux1[['before_after', 'sales']].groupby( 'before_after' ).sum().reset_index()

plt.subplot( 2, 2, 4 )
sns.barplot( x='before_after', y='sales', data=aux2 );

# %% [markdown]
# ### **H12.** Lojas deveriam vender menos aos finais de semana.
# **VERDADEIRA** Lojas vendem menos nos final de semana

# %%
aux1 = df4[['day_of_week', 'sales']].groupby( 'day_of_week' ).sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.barplot( x='day_of_week', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='day_of_week', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### **H13.** Lojas deveriam vender menos durante os feriados escolares.
# **VERDADEIRA** Lojas vendem menos durante os feriadso escolares, except os meses de Julho e Agosto.

# %%
aux1 = df4[['school_holiday', 'sales']].groupby( 'school_holiday' ).sum().reset_index()
plt.subplot( 2, 1, 1 )
sns.barplot( x='school_holiday', y='sales', data=aux1 );

aux2 = df4[['month', 'school_holiday', 'sales']].groupby( ['month','school_holiday'] ).sum().reset_index()
plt.subplot( 2, 1, 2 )
sns.barplot( x='month', y='sales', hue='school_holiday', data=aux2 );

# %% [markdown]
# ### 4.2.1. Summary of Hypotheses

# %%
tab =[['Hipoteses', 'Conclusao', 'Relevancia'],
      ['H1', 'Falsa', 'Baixa'],  
      ['H2', 'Falsa', 'Media'],  
      ['H3', 'Falsa', 'Media'],
      ['H4', 'Falsa', 'Baixa'],
      ['H5', '-', '-'],
      ['H7', 'Falsa', 'Baixa'],
      ['H8', 'Falsa', 'Media'],
      ['H9', 'Falsa', 'Alta'],
      ['H10', 'Falsa', 'Alta'],
      ['H11', 'Verdadeira', 'Alta'],
      ['H12', 'Verdadeira', 'Alta'],
      ['H13', 'Verdadeira', 'Baixa'],
     ]  
print( tabulate( tab, headers='firstrow' ) )
# Out:
# Hipoteses    Conclusao    Relevancia
# -----------  -----------  ------------
# H1           Falsa        Baixa
# H2           Falsa        Media
# H3           Falsa        Media
# H4           Falsa        Baixa
# H5           -            -
# H7           Falsa        Baixa
# H8           Falsa        Media
# H9           Falsa        Alta
# H10          Falsa        Alta
# H11          Verdadeira   Alta
# H12          Verdadeira   Alta
# H13          Verdadeira   Baixa

# %% [markdown]
# ## 4.3. Multivariate Analysis

# %% [markdown]
# ### 4.3.1. Numerical Attributes

# %%
correlation = num_attributes.corr( method='pearson' )
sns.heatmap( correlation, annot=True );

# %% [markdown]
# ### 4.3.2. Categorical Attributes

# %%
# only categorical data
a = df4.select_dtypes( include='object' )

# Calculate cramer V
a1 = cramer_v( a['state_holiday'], a['state_holiday'] )
a2 = cramer_v( a['state_holiday'], a['store_type'] )
a3 = cramer_v( a['state_holiday'], a['assortment'] )

a4 = cramer_v( a['store_type'], a['state_holiday'] )
a5 = cramer_v( a['store_type'], a['store_type'] )
a6 = cramer_v( a['store_type'], a['assortment'] )

a7 = cramer_v( a['assortment'], a['state_holiday'] )
a8 = cramer_v( a['assortment'], a['store_type'] )
a9 = cramer_v( a['assortment'], a['assortment'] )

# Final dataset
d = pd.DataFrame( {'state_holiday': [a1, a2, a3], 
               'store_type': [a4, a5, a6],
               'assortment': [a7, a8, a9]  })
d = d.set_index( d.columns )

sns.heatmap( d, annot=True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5.0. STEP 05 - DATA PREPARATION

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1. Normalization

# %%
# there are no attributes that have a normal distribution, so this step was skipped

# %% [markdown]
# ## 5.2. Rescaling

# %%
rs = RobustScaler()
mms = MinMaxScaler()

# competition distance
df5['competition_distance'] = rs.fit_transform( df5[['competition_distance']].values )
#pickle.dump( rs, open( 'parameter/competition_distance_scaler.pkl', 'wb') )

# competition time month
df5['competition_time_month'] = rs.fit_transform( df5[['competition_time_month']].values )
#pickle.dump( rs, open( 'parameter/competition_time_month_scaler.pkl', 'wb') )

# promo time week
df5['promo_time_week'] = mms.fit_transform( df5[['promo_time_week']].values )
#pickle.dump( rs, open( 'parameter/promo_time_week_scaler.pkl', 'wb') )

# year
df5['year'] = mms.fit_transform( df5[['year']].values )
#pickle.dump( mms, open( 'parameter/year_scaler.pkl', 'wb') )

# %% [markdown]
# ## 5.3. Transformation

# %% [markdown]
# ### 5.3.1. Encoding

# %%
# state_holiday - One Hot Encoding
df5 = pd.get_dummies( df5, prefix=['state_holiday'], columns=['state_holiday'] )

# store_type - Label Encoding
le = LabelEncoder()
df5['store_type'] = le.fit_transform( df5['store_type'] )
#pickle.dump( le, open( 'parameter/store_type_scaler.pkl', 'wb') )

# assortment - Ordinal Encoding
assortment_dict = {'basic': 1,  'extra': 2, 'extended': 3}
df5['assortment'] = df5['assortment'].map( assortment_dict )

# %% [markdown]
# ### 5.3.2. Response Variable Transformation

# %%
df5['sales'] = np.log1p( df5['sales'] )

# %% [markdown]
# ### 5.3.3. Nature Transformation

# %%
# day of week
df5['day_of_week_sin'] = df5['day_of_week'].apply( lambda x: np.sin( x * ( 2. * np.pi/7 ) ) )
df5['day_of_week_cos'] = df5['day_of_week'].apply( lambda x: np.cos( x * ( 2. * np.pi/7 ) ) )

# month
df5['month_sin'] = df5['month'].apply( lambda x: np.sin( x * ( 2. * np.pi/12 ) ) )
df5['month_cos'] = df5['month'].apply( lambda x: np.cos( x * ( 2. * np.pi/12 ) ) )

# day 
df5['day_sin'] = df5['day'].apply( lambda x: np.sin( x * ( 2. * np.pi/30 ) ) )
df5['day_cos'] = df5['day'].apply( lambda x: np.cos( x * ( 2. * np.pi/30 ) ) )

# week of year
df5['week_of_year_sin'] = df5['week_of_year'].apply( lambda x: np.sin( x * ( 2. * np.pi/52 ) ) )
df5['week_of_year_cos'] = df5['week_of_year'].apply( lambda x: np.cos( x * ( 2. * np.pi/52 ) ) )

# %% [markdown]
# # 6.0. STEP 06 - FEATURE SELECTION

# %%
df6 = df5.copy()

# %% [markdown]
# ## 6.1. Split dataframe into training and test dataset

# %%
cols_drop = ['week_of_year', 'day', 'month', 'day_of_week', 'promo_since', 'competition_since', 'year_week' ]
df6 = df6.drop( cols_drop, axis=1 )

# %%
# training dataset
X_train = df6[df6['date'] < '2015-06-19']
y_train = X_train['sales']

# test dataset
X_test = df6[df6['date'] >= '2015-06-19']
y_test = X_test['sales']

print( 'Training Min Date: {}'.format( X_train['date'].min() ) )
print( 'Training Max Date: {}'.format( X_train['date'].max() ) )

print( '\nTest Min Date: {}'.format( X_test['date'].min() ) )
print( 'Test Max Date: {}'.format( X_test['date'].max() ) )
# Out:
# Training Min Date: 2013-01-01 00:00:00
# Training Max Date: 2015-06-18 00:00:00
#
# Test Min Date: 2015-06-19 00:00:00
# Test Max Date: 2015-07-31 00:00:00

# %% [markdown]
# ## 6.2. Boruta as Feature Selector

# %%
## training and test dataset for Boruta
#X_train_n = X_train.drop( ['date', 'sales'], axis=1 ).values
#y_train_n = y_train.values.ravel()
#
## define RandomForestRegressor
#rf = RandomForestRegressor( n_jobs=-1 )
#
## define Boruta
#boruta = BorutaPy( rf, n_estimators='auto', verbose=2, random_state=42 ).fit( X_train_n, y_train_n )

# %% [markdown]
# ### 6.2.1. Best Features from Boruta

# %%
#cols_selected = boruta.support_.tolist()
#
## best features
#X_train_fs = X_train.drop( ['date', 'sales'], axis=1 )
#cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()
#
## not selected boruta
#cols_not_selected_boruta = list( np.setdiff1d( X_train_fs.columns, cols_selected_boruta ) )

# %% [markdown]
# ## 6.3. Manual Feature Selection

# %%
cols_selected_boruta = [
    'store',
    'promo',
    'store_type',
    'assortment',
    'competition_distance',
    'competition_open_since_month',
    'competition_open_since_year',
    'promo2',
    'promo2_since_week',
    'promo2_since_year',
    'competition_time_month',
    'promo_time_week',
    'day_of_week_sin',
    'day_of_week_cos',
    'month_sin',
    'month_cos',
    'day_sin',
    'day_cos',
    'week_of_year_sin',
    'week_of_year_cos']

# columns to add
feat_to_add = ['date', 'sales']

cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend( feat_to_add )

# %% [markdown]
# # 7.0. STEP 07 - MACHINE LEARNING MODELLING

# %%
x_train = X_train[ cols_selected_boruta ]
x_test = X_test[ cols_selected_boruta ]

# Time Series Data Preparation
x_training = X_train[ cols_selected_boruta_full ]

# %% [markdown]
# ## 7.1. Average Model

# %%
aux1 = x_test.copy()
aux1['sales'] = y_test.copy()

# prediction
aux2 = aux1[['store', 'sales']].groupby( 'store' ).mean().reset_index().rename( columns={'sales': 'predictions'} )
aux1 = pd.merge( aux1, aux2, how='left', on='store' )
yhat_baseline = aux1['predictions']

# performance
baseline_result = ml_error( 'Average Model', np.expm1( y_test ), np.expm1( yhat_baseline ) )
baseline_result
# Out:
#       Model Name          MAE      MAPE         RMSE
# 0  Average Model  1354.800353  0.455051  1835.135542

# %% [markdown]
# ## 7.2. Linear Regression Model

# %%
# model
lr = LinearRegression().fit( x_train, y_train )

# prediction
yhat_lr = lr.predict( x_test )

# performance
lr_result = ml_error( 'Linear Regression', np.expm1( y_test ), np.expm1( yhat_lr ) )
lr_result
# Out:
#           Model Name          MAE      MAPE         RMSE
# 0  Linear Regression  1867.089774  0.292694  2671.049215

# %% [markdown]
# ### 7.2.1. Linear Regression Model - Cross Validation

# %%
lr_result_cv = cross_validation( x_training, 5, 'Linear Regression', lr, verbose=False )
lr_result_cv
# Out:
#           Model Name              MAE CV       MAPE CV             RMSE CV
# 0  Linear Regression  2081.73 +/- 295.63  0.3 +/- 0.02  2952.52 +/- 468.37

# %% [markdown]
# ## 7.3. Linear Regression Regularized Model - Lasso

# %%
# model
lrr = Lasso( alpha=0.01 ).fit( x_train, y_train )

# prediction
yhat_lrr = lrr.predict( x_test )

# performance
lrr_result = ml_error( 'Linear Regression - Lasso', np.expm1( y_test ), np.expm1( yhat_lrr ) )
lrr_result
# Out:
#                   Model Name          MAE      MAPE         RMSE
# 0  Linear Regression - Lasso  1891.704881  0.289106  2744.451737

# %% [markdown]
# ### 7.3.1.  Lasso - Cross Validation

# %%
lrr_result_cv = cross_validation( x_training, 5, 'Lasso', lrr, verbose=False )
lrr_result_cv
# Out:
#   Model Name             MAE CV        MAPE CV             RMSE CV
# 0      Lasso  2116.38 +/- 341.5  0.29 +/- 0.01  3057.75 +/- 504.26

# %% [markdown]
# ## 7.4. Random Forest Regressor

# %%
# model
rf = RandomForestRegressor( n_estimators=100, n_jobs=-1, random_state=51 ).fit( x_train, y_train )

# prediction
yhat_rf = rf.predict( x_test )

# performance
rf_result = ml_error( 'Random Forest Regressor', np.expm1( y_test ), np.expm1( yhat_rf ) )
rf_result
# Out:
#                 Model Name         MAE      MAPE         RMSE
# 0  Random Forest Regressor  678.898453  0.100002  1008.664653

# %% [markdown]
# ### 7.4.1.  Random Forest Regressor - Cross Validation

# %%
rf_result_cv = cross_validation( x_training, 5, 'Random Forest Regressor', rf, verbose=True )
rf_result_cv
# Out:
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
#                 Model Name             MAE CV        MAPE CV            RMSE CV
# 0  Random Forest Regressor  836.74 +/- 215.91  0.12 +/- 0.02  1255.75 +/- 315.5

# %% [markdown]
# ## 7.5. XGBoost Regressor

# %%
# model
model_xgb = xgb.XGBRegressor( objective='reg:squarederror',
                              n_estimators=100, 
                              eta=0.01, 
                              max_depth=10, 
                              subsample=0.7,
                              colsample_bytee=0.9 ).fit( x_train, y_train )

# prediction
yhat_xgb = model_xgb.predict( x_test )

# performance
xgb_result = ml_error( 'XGBoost Regressor', np.expm1( y_test ), np.expm1( yhat_xgb ) )
xgb_result
# Out:
# [00:12:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "colsample_bytee" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#           Model Name        MAE      MAPE         RMSE
# 0  XGBoost Regressor  6683.6064  0.949503  7330.742181

# %% [markdown]
# ### 7.5.1. XGBoost Regressor - Cross Validation

# %%
xgb_result_cv = cross_validation( x_training, 5, 'XGBoost Regressor', model_xgb, verbose=True )
xgb_result_cv
# Out:
# KFold Number: 5
# [00:13:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "colsample_bytee" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
#
# KFold Number: 4
# [00:14:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "colsample_bytee" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
#
# KFold Number: 3
# [00:16:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "colsample_bytee" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
#
# KFold Number: 2
# [00:17:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "colsample_bytee" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
#
# KFold Number: 1
# [00:18:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "colsample_bytee" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#           Model Name              MAE CV       MAPE CV             RMSE CV
# 0  XGBoost Regressor  7047.97 +/- 587.65  0.95 +/- 0.0  7714.03 +/- 688.72

# %% [markdown]
# ### 7.6. Light Gradient Boost Machine

# %%
# model
model_lgbm = LGBMRegressor(n_estimators=1000,max_depth=8).fit( x_train, y_train )

# prediction
yhat_lgbm = model_lgbm.predict( x_test )

# performance
lgbm_result = ml_error( 'Light GBM', np.expm1( y_test ), np.expm1( yhat_lgbm ) )
lgbm_result
# Out:
#   Model Name         MAE      MAPE         RMSE
# 0  Light GBM  717.311745  0.107085  1034.013342

# %% [markdown]
# ### 7.6.1. Light Gradient Boost Machine - Cross Validation

# %%
lgbm_result_cv = cross_validation( x_training, 5, 'Light GBM', model_lgbm, verbose=True )
lgbm_result_cv
# Out:
# KFold Number: 5
#
# KFold Number: 4
#
# KFold Number: 3
#
# KFold Number: 2
#
# KFold Number: 1
#   Model Name             MAE CV        MAPE CV             RMSE CV
# 0  Light GBM  903.64 +/- 132.51  0.13 +/- 0.01  1289.87 +/- 181.18

# %% [markdown]
# ## 7.6. Compare Model's Performance

# %% [markdown]
# ### 7.6.1. Single Performance

# %%
modelling_result = pd.concat( [baseline_result, lr_result, lrr_result, rf_result, xgb_result, lgbm_result] )
modelling_result.sort_values( 'RMSE' )
# Out:
#                   Model Name          MAE      MAPE         RMSE
# 0    Random Forest Regressor   678.898453  0.100002  1008.664653
# 0                  Light GBM   717.311745  0.107085  1034.013342
# 0              Average Model  1354.800353  0.455051  1835.135542
# 0          Linear Regression  1867.089774  0.292694  2671.049215
# 0  Linear Regression - Lasso  1891.704881  0.289106  2744.451737
# 0          XGBoost Regressor  6683.606400  0.949503  7330.742181

# %% [markdown]
# ### 7.6.2. Real Performance - Cross Validation

# %%
modelling_result_cv = pd.concat( [lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv, lgbm_result_cv] )
modelling_result_cv.sort_values( 'RMSE CV' )
# Out:
#                 Model Name              MAE CV        MAPE CV             RMSE CV
# 0  Random Forest Regressor   836.74 +/- 215.91  0.12 +/- 0.02   1255.75 +/- 315.5
# 0                Light GBM   903.64 +/- 132.51  0.13 +/- 0.01  1289.87 +/- 181.18
# 0        Linear Regression  2081.73 +/- 295.63   0.3 +/- 0.02  2952.52 +/- 468.37
# 0                    Lasso   2116.38 +/- 341.5  0.29 +/- 0.01  3057.75 +/- 504.26
# 0        XGBoost Regressor  7047.97 +/- 587.65   0.95 +/- 0.0  7714.03 +/- 688.72

# %% [markdown]
# # 8.0. STEP 08 - HYPERPARAMETER FINE TUNING

# %% [markdown]
# ## 8.1. Grid Search

# %%
regressors = {
    'RandomForestRegressor': RandomForestRegressor(),
    'XGBRegressor': xgb.XGBRegressor(),
    'LGBMRegressor':LGBMRegressor(),
}

# %%
params = {'RandomForestRegressor': {
            'n_estimators': [16, 32, 64,128, ], 
            'max_depth': [2,4,8,16,32,64,128], 
            'max_features': ['auto'], 
            'min_samples_leaf': [1, 2, 4], 
            'min_samples_split': [2, 5, 10],
            'random_state': [42] 
        },
          'XGBRegressor' : {
            'min_child_weight': [1, 5, 10], 
            'gamma': [0.5, 1, 1.5, 2, 5],
            'max_depth': [3, 4, 5],
            'random_state': [42]
        },
           'LGBMRegressor' : {
            'min_child_weight': [1, 5, 10], 
            'min_child_samples': [10,20,30,40],
            'max_depth': [3, 4, 5],
            'learning_rate': [0.01, 0.15, 0.3],
            'random_state': [42]
        }}

# %%
results = {
    'model': [],
    'params':[],
    'MAE':[],
    'MAPE': [],
    'RMSE':[],
}

for regressor in tqdm(regressors):
    
    model = regressors[regressor]
    param = params[regressor]
    grid_params = list(ParameterGrid(param))
    
    for grid_param in tqdm(grid_params):
        model.set_params(**grid_param)
        
        model.fit(x_train, y_train)
        yhat = model.predict(x_test)

        mae = mean_absolute_error( y_test, yhat )
        mape = mean_absolute_percentage_error( y_test, yhat )
        rmse = np.sqrt( mean_squared_error( y_test, yhat ) )
        
        results['model'].append(regressor)
        results['params'].append(f'{grid_param}')
        results['MAE'].append(mae)
        results['MAPE'].append(mape)
        results['RMSE'].append(rmse)
# Out:
#   0%|                                                                                                                                           | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                                                                         | 0/252 [00:00<?, ?it/s]
#   0%|▌                                                                                                                                | 1/252 [00:10<43:41, 10.44s/it]
#   1%|█                                                                                                                              | 2/252 [00:30<1:08:16, 16.39s/it]
#   1%|█▌                                                                                                                             | 3/252 [01:14<1:58:56, 28.66s/it]
#   2%|██                                                                                                                             | 4/252 [02:45<3:40:12, 53.28s/it]
#   2%|██▌                                                                                                                            | 5/252 [02:56<2:36:15, 37.96s/it]
#   2%|███                                                                                                                            | 6/252 [03:20<2:16:30, 33.30s/it]
#   3%|███▌                                                                                                                           | 7/252 [04:30<3:05:45, 45.49s/it]
#   3%|████                                                                                                                           | 8/252 [06:09<4:14:19, 62.54s/it]
#   4%|████▌                                                                                                                          | 9/252 [06:21<3:09:09, 46.71s/it]
#   4%|█████                                                                                                                         | 10/252 [06:46<2:40:25, 39.78s/it]
#   4%|█████▌                                                                                                                        | 11/252 [07:36<2:53:11, 43.12s/it]
#   5%|██████                                                                                                                        | 12/252 [09:12<3:56:24, 59.10s/it]
#   5%|██████▌                                                                                                                       | 13/252 [09:25<3:00:05, 45.21s/it]
#   6%|███████                                                                                                                       | 14/252 [09:50<2:34:24, 38.93s/it]
#   6%|███████▌                                                                                                                      | 15/252 [10:44<2:52:36, 43.70s/it]
#   6%|████████                                                                                                                      | 16/252 [12:48<4:26:15, 67.69s/it]
#   7%|████████▌                                                                                                                     | 17/252 [13:00<3:20:20, 51.15s/it]
#   7%|█████████                                                                                                                     | 18/252 [13:25<2:48:03, 43.09s/it]
#   8%|█████████▌                                                                                                                    | 19/252 [14:14<2:54:36, 44.96s/it]
#   8%|██████████                                                                                                                    | 20/252 [16:01<4:05:31, 63.50s/it]
#   8%|██████████▌                                                                                                                   | 21/252 [16:12<3:04:11, 47.84s/it]
#   9%|███████████                                                                                                                   | 22/252 [16:39<2:39:43, 41.67s/it]
#   9%|███████████▌                                                                                                                  | 23/252 [17:25<2:43:40, 42.88s/it]
#  10%|████████████                                                                                                                  | 24/252 [18:56<3:38:07, 57.40s/it]
#  10%|████████████▌                                                                                                                 | 25/252 [19:09<2:46:09, 43.92s/it]
#  10%|█████████████                                                                                                                 | 26/252 [19:39<2:29:34, 39.71s/it]
#  73%|█████████████████████████████████████████████████████████████████████████████████████████████▋                                  | 79/108 [04:12<01:20,  2.76s/it]
#  74%|██████████████████████████████████████████████████████████████████████████████████████████████▊                                 | 80/108 [04:15<01:14,  2.67s/it]
#  75%|████████████████████████████████████████████████████████████████████████████████████████████████                                | 81/108 [04:17<01:13,  2.71s/it]
#  76%|█████████████████████████████████████████████████████████████████████████████████████████████████▏                              | 82/108 [04:20<01:11,  2.74s/it]
#  77%|██████████████████████████████████████████████████████████████████████████████████████████████████▎                             | 83/108 [04:23<01:06,  2.66s/it]
#  78%|███████████████████████████████████████████████████████████████████████████████████████████████████▌                            | 84/108 [04:25<01:03,  2.64s/it]
#  79%|████████████████████████████████████████████████████████████████████████████████████████████████████▋                           | 85/108 [04:28<01:01,  2.67s/it]
#  80%|█████████████████████████████████████████████████████████████████████████████████████████████████████▉                          | 86/108 [04:31<00:59,  2.70s/it]
#  81%|███████████████████████████████████████████████████████████████████████████████████████████████████████                         | 87/108 [04:34<00:57,  2.75s/it]
#  81%|████████████████████████████████████████████████████████████████████████████████████████████████████████▎                       | 88/108 [04:36<00:55,  2.76s/it]
#  82%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▍                      | 89/108 [04:39<00:52,  2.75s/it]
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▋                     | 90/108 [04:42<00:50,  2.78s/it]
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▊                    | 91/108 [04:45<00:49,  2.90s/it]
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████                   | 92/108 [04:50<00:53,  3.37s/it]
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                 | 93/108 [04:54<00:54,  3.64s/it]
#  87%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                | 94/108 [04:58<00:52,  3.73s/it]
#  88%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌               | 95/108 [05:02<00:48,  3.77s/it]
#  89%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊              | 96/108 [05:05<00:43,  3.63s/it]
#  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉             | 97/108 [05:09<00:39,  3.64s/it]
#  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏           | 98/108 [05:13<00:36,  3.68s/it]
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎          | 99/108 [05:16<00:33,  3.73s/it]
#  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌         | 100/108 [05:21<00:31,  3.98s/it]
#  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊        | 101/108 [05:24<00:26,  3.84s/it]
#  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉       | 102/108 [05:28<00:21,  3.64s/it]
#  95%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████      | 103/108 [05:31<00:17,  3.57s/it]
#  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎    | 104/108 [05:35<00:14,  3.58s/it]
#  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 105/108 [05:38<00:10,  3.42s/it]
#  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 106/108 [05:41<00:06,  3.32s/it]
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 107/108 [05:44<00:03,  3.24s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 108/108 [05:47<00:00,  3.22s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [16:39:26<00:00, 19988.96s/it]

# %%
results = pd.DataFrame(results).sort_values('MAE', ascending = False)
results.head(10)
# Out:
#              model                                             params      MAE    MAPE      RMSE
# 297  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 303  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 308  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 307  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 306  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 304  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 305  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 302  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 301  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321
# 300  LGBMRegressor  {'learning_rate': 0.01, 'max_depth': 3, 'min_c...  0.28287  0.0324  0.367321

# %%
results.params.values
# Out:
# array(["{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.01, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 3, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 3, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 3, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 3, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 3, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 3, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 3, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 3, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 3, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 3, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 3, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 3, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 3, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.15, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 4, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 4, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 4, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 4, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 4, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 4, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 4, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 4, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 4, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 4, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 4, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 4, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 4, 'min_child_weight': 10, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 5, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 5, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 5, 'max_depth': 5, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 40, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 5, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 5, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 1, 'max_depth': 5, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 5, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 5, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 5, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 5, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 10, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 30, 'min_child_weight': 1, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 5, 'min_child_weight': 5, 'random_state': 42}",
#        "{'gamma': 1.5, 'max_depth': 5, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 2, 'max_depth': 5, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 5, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 1, 'random_state': 42}",
#        "{'learning_rate': 0.3, 'max_depth': 5, 'min_child_samples': 20, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 5, 'min_child_weight': 10, 'random_state': 42}",
#        "{'gamma': 0.5, 'max_depth': 5, 'min_child_weight': 1, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 16, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 32, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 64, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 128, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}",
#        "{'max_depth': 64, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 128, 'random_state': 42}"],
#       dtype=object)

# %%
#XGBoost
#param = {
#    'n_estimators': [1500, 1700, 2500, 3000, 3500],
#    'eta': [0.01, 0.03],
#    'max_depth': [3, 5, 9],
#    'subsample': [0.1, 0.5, 0.7],
#    'colsample_bytree': [0.3, 0.7, 0.9],
#    'min_child_weight': [3, 8, 15]
#        }
#
#MAX_EVAL = 5

# %%
#XGBoost
#final_result = pd.DataFrame()
#
#for i in range( MAX_EVAL ):
#    # choose values for parameters randomly
#    hp = { k: random.sample( v, 1 )[0] for k, v in param.items() }
#    print( hp )
#    
#    # model
#    model_xgb = xgb.XGBRegressor( objective='reg:squarederror',
#                                  n_estimators=hp['n_estimators'], 
#                                  eta=hp['eta'], 
#                                  max_depth=hp['max_depth'], 
#                                  subsample=hp['subsample'],
#                                  colsample_bytee=hp['colsample_bytree'],
#                                  min_child_weight=hp['min_child_weight'] )
#
#    # performance
#    result = cross_validation( x_training, 5, 'XGBoost Regressor', model_xgb, verbose=True )
#    final_result = pd.concat( [final_result, result] )
#        
#final_result

# %%
#final_result

# %% [markdown]
# ## 8.2. Final Model

# %%
#LGBM
#param_tuned = {'learning_rate': 0.01, 'max_depth': 3, 'min_child_samples': 10, 'min_child_weight': 1, 'random_state': 42}

# %%
#XGB
param_tuned = {
'n_estimators': 3000,
 'eta': 0.03,
'max_depth': 5,
'subsample': 0.7,
'colsample_bytree': 0.7,
'min_child_weight': 3 
    }

# %%
# model
# model_lgbm_tuned = LGBMRegressor( 
#                                     learning_rate=param_tuned['learning_rate'], 
#                                     max_depth=param_tuned['max_depth'], 
#                                     min_child_samples=param_tuned['min_child_samples'], 
#                                     min_child_weight=param_tuned['min_child_weight'],
#                                     random_state=param_tuned['random_state'] ).fit( x_train, y_train )

# # prediction
# yhat_lgbm_tuned = model_lgbm_tuned.predict( x_test )

# # performance
# lgbm_result_tuned = ml_error( 'Light GBM', np.expm1( y_test ), np.expm1( yhat_lgbm_tuned ) )
# lgbm_result_tuned
# Out:
#   Model Name          MAE      MAPE         RMSE
# 0  Light GBM  1939.262819  0.294911  2823.307613

# %%
lgbm_result
#O resultado do LGBM foi melhor sem o fine tuning
# Out:
#   Model Name         MAE      MAPE         RMSE
# 0  Light GBM  717.311745  0.107085  1034.013342

# %%
# model
model_xgb_tuned = xgb.XGBRegressor( objective='reg:squarederror',
                                    n_estimators=param_tuned['n_estimators'], 
                                    eta=param_tuned['eta'], 
                                    max_depth=param_tuned['max_depth'], 
                                    subsample=param_tuned['subsample'],
                                    colsample_bytee=param_tuned['colsample_bytree'],
                                    min_child_weight=param_tuned['min_child_weight'] ).fit( x_train, y_train )

# prediction
yhat_xgb_tuned = model_xgb_tuned.predict( x_test )

# performance
xgb_result_tuned = ml_error( 'XGBoost Regressor', np.expm1( y_test ), np.expm1( yhat_xgb_tuned ) )
xgb_result_tuned
# Out:
# [21:30:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "colsample_bytee" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#           Model Name         MAE      MAPE         RMSE
# 0  XGBoost Regressor  760.056876  0.114527  1088.444637

# %%
mpe = mean_percentage_error( np.expm1( y_test ), np.expm1( yhat_xgb_tuned ) )
mpe
# Out:
# -0.019542777303957214

# %% [markdown]
# # 9.0. STEP 09 - TRANSLATION AND INTERPRETATION OF THE ERROR

# %%
#O LGBM foi escolhido pois o MAPE foi menor que o do XGB
df9 = X_test[ cols_selected_boruta_full ]

# rescale
df9['sales'] = np.expm1( df9['sales'] )
df9['predictions'] = np.expm1( yhat_lgbm )

# %% [markdown]
# ## 9.1. Business Performance

# %%
# sum of predictions
df91 = df9[['store', 'predictions']].groupby( 'store' ).sum().reset_index()

# MAE and MAPE
df9_aux1 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply( lambda x: mean_absolute_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAE'})
df9_aux2 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply( lambda x: mean_absolute_percentage_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAPE'})

# Merge
df9_aux3 = pd.merge( df9_aux1, df9_aux2, how='inner', on='store' )
df92 = pd.merge( df91, df9_aux3, how='inner', on='store' )

# Scenarios
df92['worst_scenario'] = df92['predictions'] - df92['MAE']
df92['best_scenario'] = df92['predictions'] + df92['MAE']

# order columns
df92 = df92[['store', 'predictions', 'worst_scenario', 'best_scenario', 'MAE', 'MAPE']]

# %%
df92.sort_values( 'MAPE', ascending=False ).head()
# Out:
#      store    predictions  worst_scenario  best_scenario          MAE      MAPE
# 291    292  107550.008120   104107.981491  110992.034750  3442.026629  0.605530
# 908    909  227054.863900   219153.275215  234956.452585  7901.588685  0.524330
# 594    595  345296.291934   340325.570094  350267.013773  4970.721840  0.342054
# 901    902  196944.344672   195619.038059  198269.651285  1325.306613  0.334279
# 875    876  192250.795377   188076.590830  196424.999925  4174.204547  0.317237

# %%
sns.scatterplot( x='store', y='MAPE', data=df92 )
# Out:
# <AxesSubplot:xlabel='store', ylabel='MAPE'>

# %% [markdown]
# ## 9.2. Total Performance

# %%
df93 = df92[['predictions', 'worst_scenario', 'best_scenario']].apply( lambda x: np.sum( x ), axis=0 ).reset_index().rename( columns={'index': 'Scenario', 0:'Values'} )
df93['Values'] = df93['Values'].map( 'R${:,.2f}'.format )
df93
# Out:
#          Scenario            Values
# 0     predictions  R$287,264,858.64
# 1  worst_scenario  R$286,461,515.21
# 2   best_scenario  R$288,068,202.08

# %% [markdown]
# ## 9.3. Machine Learning Performance

# %%
df9['error'] = df9['sales'] - df9['predictions']
df9['error_rate'] = df9['predictions'] / df9['sales']

# %%
plt.subplot( 2, 2, 1 )
sns.lineplot( x='date', y='sales', data=df9, label='SALES' )
sns.lineplot( x='date', y='predictions', data=df9, label='PREDICTIONS' )

plt.subplot( 2, 2, 2 )
sns.lineplot( x='date', y='error_rate', data=df9 )
plt.axhline( 1, linestyle='--')

plt.subplot( 2, 2, 3 )
sns.distplot( df9['error'] )

plt.subplot( 2, 2, 4 )
sns.scatterplot( df9['predictions'], df9['error'] )
# Out:
# <AxesSubplot:xlabel='predictions', ylabel='error'>
